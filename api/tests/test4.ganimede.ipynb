# %%
print("printing things")from time import sleepsleep(3)print("sddf")
# Out:
# printing things
# sddf

# %% [markdown]
# # Heading 1

# %%
print("some")
# Out:
# some

# %% [markdown]
# ### Heading 3with some text below it

# %%
print("some more")
# Out:
# some more

# %% [markdown]
# # Another Heading 1

# %%
print('with some code in it')
# Out:
# with some code in it
